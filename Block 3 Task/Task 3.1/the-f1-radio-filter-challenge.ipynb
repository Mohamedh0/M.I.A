# %% [markdown]
# # **Important Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Load and Preprocess the dataset**

# %%
df = pd.read_csv("/content/train.csv")
df.head()
# Out:
#    message_id  num_links  num_words  has_offer  sender_score  all_caps  \
# 0           1          3         98          1      0.718607         0
# 1           2          0        170          0      0.698901         1
# 2           3          0         38          0      0.620466         0
# 3           4          0        116          0      0.701755         0
# 4           5          3         89          1      0.583621         1
#
#    is_spam
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19100 entries, 0 to 19099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   message_id    19100 non-null  int64
#  1   num_links     19100 non-null  int64
#  2   num_words     19100 non-null  int64
#  3   has_offer     19100 non-null  int64
#  4   sender_score  19100 non-null  float64
#  5   all_caps      19100 non-null  int64
#  6   is_spam       19100 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 1.0 MB

# %%
# Check for null values
df.isna().sum()
# Out:
# message_id      0
# num_links       0
# num_words       0
# has_offer       0
# sender_score    0
# all_caps        0
# is_spam         0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['is_spam'].value_counts() # Dataset is imbalanced
# Out:
# is_spam
# 0    17354
# 1     1746
# Name: count, dtype: int64

# %%
# Drop unnecessary columns
df.drop(['message_id'], axis=1,inplace=True)

# %%
# Feature Engineering
df['links_per_word'] = df['num_links'] / (df['num_words'] + 1)
df.head()
# Out:
#    num_links  num_words  has_offer  sender_score  all_caps  is_spam  \
# 0          3         98          1      0.718607         0        0
# 1          0        170          0      0.698901         1        0
# 2          0         38          0      0.620466         0        0
# 3          0        116          0      0.701755         0        0
# 4          3         89          1      0.583621         1        1
#
#    links_per_word
# 0        0.030303
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.033333

# %%
df.describe()
# Out:
#           num_links     num_words     has_offer  sender_score      all_caps  \
# count  19100.000000  19100.000000  19100.000000  19100.000000  19100.000000
# mean       1.498272    109.651780      0.303298      0.694174      0.097853
# std        1.221115     51.974463      0.459695      0.188285      0.297124
# min        0.000000     20.000000      0.000000      0.000000      0.000000
# 25%        1.000000     65.000000      0.000000      0.566990      0.000000
# 50%        1.000000    110.000000      0.000000      0.699204      0.000000
# 75%        2.000000    155.000000      1.000000      0.834200      0.000000
# max        9.000000    199.000000      1.000000      1.000000      1.000000
#
#             is_spam  links_per_word
# count  19100.000000    19100.000000
# mean       0.091414        0.018992
# std        0.288204        0.023753
# min        0.000000        0.000000
# 25%        0.000000        0.005435
# 50%        0.000000        0.012346
# 75%        0.000000        0.024390
# max        1.000000        0.318182

# %%
df.corr()
# Out:
#                 num_links  num_words  has_offer  sender_score  all_caps  \
# num_links        1.000000   0.003194  -0.004057     -0.002424  0.000682
# num_words        0.003194   1.000000  -0.005518      0.004276  0.001451
# has_offer       -0.004057  -0.005518   1.000000     -0.002169 -0.001098
# sender_score    -0.002424   0.004276  -0.002169      1.000000  0.018184
# all_caps         0.000682   0.001451  -0.001098      0.018184  1.000000
# is_spam          0.322846   0.000849   0.368503     -0.088210  0.207979
# links_per_word   0.657699  -0.488613  -0.006697     -0.007697 -0.002816
#
#                  is_spam  links_per_word
# num_links       0.322846        0.657699
# num_words       0.000849       -0.488613
# has_offer       0.368503       -0.006697
# sender_score   -0.088210       -0.007697
# all_caps        0.207979       -0.002816
# is_spam         1.000000        0.210271
# links_per_word  0.210271        1.000000

# %%
X = df.drop(['is_spam'], axis=1).values
y = df['is_spam'].values

# %%
X
# Out:
# array([[3.00000000e+00, 9.80000000e+01, 1.00000000e+00, 7.18607000e-01,
#         0.00000000e+00, 3.03030303e-02],
#        [0.00000000e+00, 1.70000000e+02, 0.00000000e+00, 6.98901226e-01,
#         1.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.80000000e+01, 0.00000000e+00, 6.20465534e-01,
#         0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 1.45000000e+02, 0.00000000e+00, 6.00568655e-01,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.78000000e+02, 0.00000000e+00, 6.75468409e-01,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.00000000e+01, 0.00000000e+00, 6.97732338e-01,
#         0.00000000e+00, 0.00000000e+00]])

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Stratified train-validation split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Verify stratification
print("Training set class distribution:", np.bincount(y_train))
print("Validation set class distribution:", np.bincount(y_val))
# Out:
# Training set class distribution: [13883  1397]
# Validation set class distribution: [3471  349]

# %%
scaler = scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# %% [markdown]
# # **Logistic Regression**

# %%
class LogisticRegression:
    def __init__(self, learning_rate=0.01, max_iterations=1000, lambda_reg=0.1,
                 reg_type='l2', class_weight={0: 1.5, 1: 15}):
        self.learning_rate = learning_rate
        self.max_iterations = max_iterations
        self.lambda_reg = lambda_reg
        self.reg_type = reg_type.lower()
        self.class_weight = class_weight
        self.weights = None
        self.bias = None

    def sigmoid(self, z):
        """Sigmoid activation with clipping to avoid overflow."""
        z = np.clip(z, -500, 500)
        return 1 / (1 + np.exp(-z))

    def log_loss(self, y_true, y_pred):
        """Binary cross-entropy loss with regularization."""
        epsilon = 1e-15
        y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
        loss = -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

        # Add regularization penalty
        if self.reg_type == 'l1':
            reg_term = self.lambda_reg * np.sum(np.abs(self.weights))
        elif self.reg_type == 'l2':
            reg_term = self.lambda_reg * np.sum(self.weights ** 2) / 2
        else:
            raise ValueError("reg_type must be 'l1' or 'l2'")

        return loss + reg_term

    def _compute_sample_weights(self, y):
        if self.class_weight == 'balanced':
            # Inverse frequency weighting
            classes, counts = np.unique(y, return_counts=True)
            total = len(y)
            weight_dict = {cls: total / (2 * count) for cls, count in zip(classes, counts)}
        elif isinstance(self.class_weight, dict):
            # Manual class weights
            weight_dict = self.class_weight
        else:
            # No weighting
            return np.ones_like(y)

        return np.array([weight_dict[label] for label in y])

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        sample_weights = self._compute_sample_weights(y)

        for _ in range(self.max_iterations):
            # Forward pass
            linear_model = np.dot(X, self.weights) + self.bias
            y_pred = self.sigmoid(linear_model)

            # Compute weighted error
            error = y_pred - y
            weighted_error = error * sample_weights

            # Regularization gradient
            if self.reg_type == 'l1':
                reg_grad = self.lambda_reg * np.sign(self.weights)
            elif self.reg_type == 'l2':
                reg_grad = self.lambda_reg * self.weights
            else:
                raise ValueError("reg_type must be 'l1' or 'l2'")

            # Gradients
            dw = (1 / n_samples) * np.dot(X.T, weighted_error) + (reg_grad / n_samples)
            db = (1 / n_samples) * np.sum(weighted_error)

            # Parameter update
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict_proba(self, X):
      """Predict probabilities for input samples."""
      return self.sigmoid(np.dot(X, self.weights) + self.bias)

    def predict(self, X, threshold=0.5):
      """Predict binary class labels based on a threshold."""
      return (self.predict_proba(X) >= threshold).astype(int)

# %%
def grid_search(X_train, y_train, X_val, y_val, param_grid):
    best_log_loss = float('inf')
    best_params = None
    best_model = None

    # Try every combination of parameters
    for lr in param_grid['learning_rate']:
        for lam in param_grid['lambda_reg']:
            for max_iter in param_grid['max_iterations']:
                for reg_type in param_grid['reg_type']:
                    for class_weight in param_grid['class_weights']:

                        # Create model with given hyperparameters
                        model = LogisticRegression(
                            learning_rate=lr,
                            max_iterations=max_iter,
                            lambda_reg=lam,
                            reg_type=reg_type,
                            class_weight = class_weight
                        )

                        # Train model
                        model.fit(X_train, y_train)

                        # Evaluate on validation set
                        y_pred_proba = model.predict_proba(X_val)
                        log_loss = model.log_loss(y_val, y_pred_proba)
                        print(f"LR: {lr}, Lambda: {lam}, MaxIter: {max_iter}, Reg: {reg_type}, Class Weight: {class_weight} ,LogLoss: {log_loss:.4f}")

                        # Track best model
                        if log_loss < best_log_loss:
                            best_log_loss = log_loss
                            best_params = {
                                'learning_rate': lr,
                                'lambda_reg': lam,
                                'max_iterations': max_iter,
                                'reg_type': reg_type,
                                'class_weight': class_weight
                            }
                            best_model = model

    return best_model, best_params, best_log_loss

# %%
param_grid = {
    'learning_rate': [ 0.03, 0.05, 0.01, 0.1,0.2],
    'lambda_reg': [ 0.0001, 0.001, 0.01],
    'max_iterations': [3000, 4000, 5000, 6000],
    'reg_type': ['L1','L2'],
    'class_weights': [ None, 'balanced', {0: 3, 1: 6}]
}

best_model, best_params, best_log_loss = grid_search(
    X_train_scaled, y_train, X_val_scaled, y_val, param_grid
)

print("\n Best Parameters:", best_params)
print(f" Best Validation LogLoss: {best_log_loss:.4f}")
# Out:
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1658
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3167
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1732
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1657
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3165
# LR: 0.03, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1731
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1637
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3124
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1730
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1635
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3122
# LR: 0.03, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1626
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3102
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1624
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3100
# LR: 0.03, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1728
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1620
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3089
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1619
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3088
# LR: 0.03, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1728
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1694
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3211
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1778
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1674
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3194
# LR: 0.03, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1765
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1674
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3169
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1777
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1656
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3154
# LR: 0.03, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1665
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3148
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1648
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3134
# LR: 0.03, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1661
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3136
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1644
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3123
# LR: 0.03, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.2046
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3652
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2239
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1852
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3486
# LR: 0.03, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2106
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.2051
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3624
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2245
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1865
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.03, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2119
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.2060
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3610
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2249
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1882
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3469
# LR: 0.03, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2126
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.2069
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3605
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2251
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1899
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3469
# LR: 0.03, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2129
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1626
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3102
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1624
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3100
# LR: 0.05, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1728
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1618
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3084
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1617
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3083
# LR: 0.05, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1728
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1616
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3076
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1614
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3075
# LR: 0.05, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1615
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3073
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1614
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3071
# LR: 0.05, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1665
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3148
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1648
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3134
# LR: 0.05, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1660
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3131
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1643
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.05, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1659
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3124
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1643
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3111
# LR: 0.05, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1659
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3121
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1644
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3108
# LR: 0.05, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.2060
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3610
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2249
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1882
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3469
# LR: 0.05, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2126
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.2075
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3605
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2252
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1909
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3469
# LR: 0.05, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2130
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.2088
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3605
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2252
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1932
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3470
# LR: 0.05, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2131
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.2098
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3606
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1950
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3471
# LR: 0.05, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1871
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3566
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1777
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1870
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3564
# LR: 0.01, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1775
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1790
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3415
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1756
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1788
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3413
# LR: 0.01, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1754
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1741
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3323
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1745
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1739
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3322
# LR: 0.01, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1743
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1709
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3263
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1739
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1707
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3261
# LR: 0.01, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1738
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1896
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3601
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1817
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1877
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3581
# LR: 0.01, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1799
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1817
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3453
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1798
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1798
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3433
# LR: 0.01, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1781
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1771
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3364
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1789
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1751
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3344
# LR: 0.01, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1773
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1740
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3305
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1784
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1721
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3286
# LR: 0.01, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1769
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.2139
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3958
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2217
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1956
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3753
# LR: 0.01, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2036
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.2090
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3836
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2219
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1899
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3636
# LR: 0.01, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2050
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.2066
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3765
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2223
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1871
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3572
# LR: 0.01, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2065
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.2054
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3720
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2228
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1857
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3534
# LR: 0.01, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2079
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1615
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3073
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1614
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3071
# LR: 0.1, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1616
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3070
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1614
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.1, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1617
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3070
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1615
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.1, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1617
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1616
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.1, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1659
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3121
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1644
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3108
# LR: 0.1, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1661
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3119
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1647
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.1, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1663
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1649
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.1, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1664
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1651
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.1, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.2098
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3606
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1950
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3471
# LR: 0.1, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.2112
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3606
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1975
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.1, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.2121
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1990
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.1, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.2126
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.2000
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.1, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1617
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1616
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.2, Lambda: 0.0001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1618
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1617
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.2, Lambda: 0.0001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1619
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1617
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.2, Lambda: 0.0001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1619
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3069
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1729
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1618
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3068
# LR: 0.2, Lambda: 0.0001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1727
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.1664
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.1651
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.2, Lambda: 0.001, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.1665
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.1653
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.2, Lambda: 0.001, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.1665
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.1653
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.2, Lambda: 0.001, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.1666
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3118
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1776
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.1654
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3105
# LR: 0.2, Lambda: 0.001, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.1764
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: None ,LogLoss: 0.2126
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: None ,LogLoss: 0.2000
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.2, Lambda: 0.01, MaxIter: 3000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: None ,LogLoss: 0.2131
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: None ,LogLoss: 0.2009
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.2, Lambda: 0.01, MaxIter: 4000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: None ,LogLoss: 0.2133
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: None ,LogLoss: 0.2012
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.2, Lambda: 0.01, MaxIter: 5000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: None ,LogLoss: 0.2134
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: balanced ,LogLoss: 0.3607
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L1, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2253
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: None ,LogLoss: 0.2013
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: balanced ,LogLoss: 0.3472
# LR: 0.2, Lambda: 0.01, MaxIter: 6000, Reg: L2, Class Weight: {0: 3, 1: 6} ,LogLoss: 0.2132
#
#  Best Parameters: {'learning_rate': 0.05, 'lambda_reg': 0.0001, 'max_iterations': 6000, 'reg_type': 'L2', 'class_weight': None}
#  Best Validation LogLoss: 0.1614

# %%
best_model.fit(X_train_scaled, y_train)

# %%
y_val_pred = best_model.predict_proba(X_val_scaled)
log_loss = best_model.log_loss(y_val, y_val_pred)

print(f"Log Loss:  {log_loss:.4f}")
# Out:
# Log Loss:  0.1614

# %%
test = pd.read_csv("/content/test.csv")
test.head()
# Out:
#    message_id  num_links  num_words  has_offer  sender_score  all_caps
# 0       20000          1         37          0      0.633935         0
# 1       20001          0        174          0      0.577815         0
# 2       20002          0        116          0      0.396098         0
# 3       20003          0        112          0      0.646450         0
# 4       20004          2         92          1      0.947398         1

# %%
features = test.drop(['message_id'],axis=1)
ids = test['message_id']
ids
# Out:
# 0      20000
# 1      20001
# 2      20002
# 3      20003
# 4      20004
#        ...
# 895    20895
# 896    20896
# 897    20897
# 898    20898
# 899    20899
# Name: message_id, Length: 900, dtype: int64

# %%
features['links_per_word'] = features['num_links'] / (features['num_words'] + 1)

# %%
features_scaled = scaler.transform(features)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
features_scaled
# Out:
# array([[-0.40651901, -1.40094477, -0.65955384, -0.32096753, -0.33078237,
#          0.31583616],
#        [-1.22512872,  1.23959789, -0.65955384, -0.62052284, -0.33078237,
#         -0.80432018],
#        [-1.22512872,  0.12170392, -0.65955384, -1.59048397, -0.33078237,
#         -0.80432018],
#        ...,
#        [-0.40651901,  0.73847301,  1.51617645,  0.26417161, -0.33078237,
#         -0.51864273],
#        [ 0.4120907 ,  1.23959789, -0.65955384, -0.60219107,  3.02313574,
#         -0.31785228],
#        [ 0.4120907 , -0.398695  , -0.65955384,  1.37254115, -0.33078237,
#          0.14158962]])

# %%
predictions = best_model.predict_proba(features_scaled)
predictions
# Out:
# array([1.67184600e-03, 5.76400249e-04, 9.10285488e-04, 4.55581945e-04,
#        7.33886864e-01, 5.81763304e-04, 1.08321071e-03, 3.27108521e-03,
#        2.13526680e-02, 6.97813683e-03, 3.09763133e-04, 5.34817725e-02,
#        5.32368025e-03, 4.38913605e-03, 2.08873374e-02, 5.17182507e-03,
#        4.48608147e-01, 4.04147829e-03, 3.75727925e-03, 1.52411750e-03,
#        1.61907346e-03, 2.18654416e-02, 5.05042560e-01, 2.42287669e-02,
#        7.72869945e-02, 3.67144954e-04, 4.45609178e-02, 1.38246155e-01,
#        1.11188516e-02, 7.00193126e-02, 7.64287849e-03, 6.15387460e-03,
#        1.68394051e-01, 2.55531147e-01, 6.81775917e-02, 1.12786506e-01,
#        9.26937447e-01, 1.54726573e-02, 2.76931324e-04, 1.50440409e-01,
#        2.63526057e-03, 1.84430215e-04, 1.22594892e-02, 3.67830567e-01,
#        1.54194380e-02, 4.59977383e-04, 1.63839432e-03, 4.20676784e-03,
#        2.08742228e-04, 1.55420384e-01, 1.43156140e-03, 2.30179479e-01,
#        9.74239232e-01, 9.69333711e-03, 8.81045712e-03, 9.48197505e-01,
#        4.23321820e-04, 7.38627071e-03, 7.41014422e-01, 1.05485973e-03,
#        1.85553954e-03, 2.22175900e-01, 7.98158012e-03, 2.91171463e-01,
#        7.20555802e-03, 3.90024551e-02, 1.58727854e-03, 2.77895325e-03,
#        1.06581469e-02, 1.43090018e-03, 9.26490956e-03, 1.47853844e-03,
#        2.52983480e-01, 5.20576571e-01, 1.24687606e-03, 2.93123254e-02,
#        3.25286702e-01, 6.67886512e-01, 6.96085127e-04, 4.99722394e-03,
#        3.30025511e-02, 1.27489228e-02, 1.14673745e-03, 2.40487440e-03,
#        4.15279542e-03, 1.65525208e-04, 4.54478607e-02, 3.50733530e-02,
#        1.10572482e-03, 3.79215137e-02, 2.97644262e-03, 1.84668896e-02,
#        1.13769851e-03, 5.25787665e-04, 1.15133957e-01, 3.95708395e-03,
#        5.76870553e-03, 1.09644693e-01, 2.60289893e-03, 2.53860113e-03,
#        3.95880284e-01, 4.71191134e-01, 2.13527599e-03, 1.60208711e-02,
#        2.21421443e-03, 3.15314353e-04, 4.43881892e-01, 6.82667367e-03,
#        6.13337635e-04, 4.99434483e-04, 1.41880166e-03, 1.26462590e-03,
#        6.35878440e-04, 1.20109392e-02, 1.80280277e-03, 2.93240985e-04,
#        9.87003662e-04, 2.01437398e-03, 1.00810758e-03, 2.02213235e-02,
#        1.22485919e-03, 8.23791895e-04, 7.91035201e-04, 8.20157806e-03,
#        2.71019184e-03, 6.30323364e-04, 3.20328986e-02, 4.87591330e-02,
#        2.26379815e-02, 8.15668476e-02, 1.17299696e-01, 1.31082859e-03,
#        1.94471950e-02, 5.12606605e-01, 2.63676919e-03, 4.69215070e-03,
#        1.10496044e-03, 4.39604295e-01, 4.68567863e-02, 9.41660968e-04,
#        3.99264485e-01, 4.17064387e-02, 1.80829904e-03, 8.82022771e-03,
#        5.00100630e-02, 1.65784817e-03, 1.13355341e-03, 2.44732327e-03,
#        1.40880587e-03, 2.41757396e-03, 4.32928351e-01, 3.04824710e-02,
#        1.60795910e-03, 1.40410711e-02, 1.37356286e-03, 1.89903374e-01,
#        2.55916164e-03, 6.51363032e-02, 1.25520792e-01, 2.51118728e-03])

# %%
submission = pd.DataFrame({
    'message_id': ids,
    'Calories': predictions
})
submission.head()
# Out:
#    message_id  Calories
# 0       20000  0.001672
# 1       20001  0.000576
# 2       20002  0.000910
# 3       20003  0.000456
# 4       20004  0.733887

# %%
submission.to_csv('submission1.csv', index=False)
